# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('/Users/prateeklodha/Desktop/data analysis/data_jobs.csv')
df['job_posted_date']=pd.to_datetime(df.job_posted_date)

# %%
df.sample(12, random_state=0)
# Out:
#              job_title_short                                 job_title  \
# 714934     Software Engineer                           Product Analyst
# 397245          Data Analyst                              Data Analyst
# 617736        Data Scientist  AVP - Data Science Team (Analytics Team)
# 624251          Data Analyst                                高级大数据开发工程师
# 263814         Data Engineer                            Data Engineers
# 130747          Data Analyst                    Marketing Data Analyst
# 458472   Senior Data Analyst            Senior Data Management Analyst
# 601012         Data Engineer          Machine Learning / Data Engineer
# 637566  Senior Data Engineer    Senior Data Center Engineer（高级数据中心工程师）
# 605112        Data Scientist                            Data Scientist
# 360765         Data Engineer                      Crash Data Processor
# 499937      Business Analyst             Business Analytics Consultant
#
# ...
